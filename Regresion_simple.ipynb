# %% [markdown]
# <a href="https://colab.research.google.com/github/JuanK-05/Regresiones_Corte_3/blob/main/Regresion_simple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: Carga el siguiente excel que esta ubicado en "/content/drive/MyDrive/Estadistica (1)/C3/datos_industrias.xlsx"

import pandas as pd

# Construct the file path
file_path = "/content/drive/MyDrive/Estadistica (1)/C3/datos_industrias.xlsx"

# Read the Excel file into a pandas DataFrame
df = pd.read_excel(file_path)

# Display the first few rows of the DataFrame (optional)
print(df.head())
# Out:
#    Tasa_Crecimiento  Inversión_Tecnología  Aumento_salario  Antigüedad(años)  \
# 0           0.00632                  2.31            0.538             6.575
# 1           0.02731                  7.07            0.469             6.421
# 2           0.02729                  7.07            0.469             7.185
# 3           0.03237                  2.18            0.458             6.998
# 4           0.06905                  2.18            0.458             7.147
#
#    Estrategias  Empleados    Salario
# 0            1       74.0  1300500.0
# 1            2       60.5  1513000.0
# 2            2       60.5  1513000.0
# 3            3       55.5  1589500.0
# 4            3       55.5  1589500.0

# %%
# prompt: Necesito un analisis de regresion lineal simple, que la variable X sea "Salario" y la variable Y sea "Tasa_Crecimiento" de nuestra base de datos

import statsmodels.api as sm
import matplotlib.pyplot as plt

# Define the independent variable (X) and the dependent variable (Y)
X = df['Salario']
Y = df['Tasa_Crecimiento']

# Add a constant to the independent variable for the intercept
X = sm.add_constant(X)

# Fit the OLS (Ordinary Least Squares) model
model = sm.OLS(Y, X).fit()

# Print the regression summary
print(model.summary())

# Make predictions
predictions = model.predict(X)

# Plot the data points and the regression line
plt.scatter(df['Salario'], Y)
plt.plot(df['Salario'], predictions, color='red')
plt.xlabel('Salario')
plt.ylabel('Tasa_Crecimiento')
plt.title('Simple Linear Regression of Tasa_Crecimiento on Salario')
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       Tasa_Crecimiento   R-squared:                       0.084
# Model:                            OLS   Adj. R-squared:                  0.082
# Method:                 Least Squares   F-statistic:                     46.26
# Date:                Tue, 13 May 2025   Prob (F-statistic):           2.94e-11
# Time:                        15:05:23   Log-Likelihood:                -1784.1
# No. Observations:                 506   AIC:                             3572.
# Df Residuals:                     504   BIC:                             3581.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -17.6469      3.147     -5.607      0.000     -23.830     -11.464
# ...
